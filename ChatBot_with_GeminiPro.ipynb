# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonheesanglee/CV_and_Portfolio/blob/main/ChatBot_with_GeminiPro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Markdown
import os
from google.colab import userdata
os.environ['GOOGLE_API_KEY'] = userdata.get('GoogleDevAPI')

# %%
# !pip install -U -qqq langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 5.6 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model='gemini-pro')
result = llm.invoke('네이버에 대한 보고서를 작성해줘')
Markdown(result.content)
# Out:
# **네이버**
#
# 네이버(Naver)는 1999년 6월 1일에 설립된 대한민국의 인터넷 검색 엔진, 포털 사이트이며, 네이버 주식회사가 운영하고 있다. 네이버는 포털 서비스, 검색 서비스, 쇼핑 서비스, 게임 서비스, 지도 서비스, 뉴스 서비스, 블로그 서비스, 카페 서비스, 지식인 서비스 등 다양한 서비스를 제공하고 있다.
#
# **역사**
#
# 네이버는 1999년 6월 1일에 이해진과 이재웅이 설립하였다. 네이버는 설립 이후 빠르게 성장하여 2000년대 초반에는 대한민국에서 가장 인기 있는 포털 사이트로 자리매김하였다. 네이버는 2003년에 주식회사로 전환되었으며, 2006년에는 코스닥에 상장되었다. 네이버는 2010년에 코스피에 상장되었으며, 2013년에는 일본에 법인을 설립하였다.
#
# **서비스**
#
# 네이버는 포털 서비스, 검색 서비스, 쇼핑 서비스, 게임 서비스, 지도 서비스, 뉴스 서비스, 블로그 서비스, 카페 서비스, 지식인 서비스 등 다양한 서비스를 제공하고 있다.
#
# * 포털 서비스: 네이버는 포털 서비스를 통해 다양한 정보를 제공하고 있다. 네이버 포털 서비스에는 뉴스, 날씨, 스포츠, 연예, IT, 경제, 생활, 여행, 쇼핑, 게임, 지도, 블로그, 카페 등 다양한 콘텐츠가 제공되고 있다.
# * 검색 서비스: 네이버는 검색 서비스를 통해 사용자가 원하는 정보를 찾을 수 있도록 도와주고 있다. 네이버 검색 서비스는 웹 검색, 이미지 검색, 동영상 검색, 뉴스 검색, 지도 검색, 블로그 검색, 카페 검색 등 다양한 검색 기능을 제공하고 있다.
# * 쇼핑 서비스: 네이버는 쇼핑 서비스를 통해 사용자가 다양한 상품을 구매할 수 있도록 도와주고 있다. 네이버 쇼핑 서비스에는 패션, 뷰티, 가전, 디지털, 생활, 여행, 식품, 건강, 스포츠, 도서 등 다양한 카테고리의 상품이 판매되고 있다.
# ...

# %%
# !pip install -U -qqq langchain tiktoken pypdf sentence_transformers chromadb cohere kaleido python-multipart openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 933.5 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.0 MB/s eta 0:00:00

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("혁신성장 정책금융에 대해서 설명해줘")
# Out:
# [Document(page_content='혁신성장 정책금융 동향 : ICT 산업을 중심으로\n  CIS이슈리포트 2022-2 호 | 3 |1. 들어가며\n▶혁신성장 정책금융기관은 건강한 혁신산업 생태계를 조성하기 위해 기업 성장에 필요한 자금을 \n지원하는 혁신성장 정책금융 제도를 시행하고 있음\n￮혁신성장 정책금융기관은 혁신성장에 대한 정의를 구체화한 정책금융 가이드라인*에 따라 혁신성장  \n산업육성을 위한 정책금융 업무를 추진 중임\n       * 혁신성장 기업발굴 및 금융지원을 위해 활용하는 기준으로 , ‘9대 테마-46개 분야-296개 품목’으로 구성\n▶혁신성장 정책금융 제도 시행 이후 공급 규모가 매년 증가하는 등, 미래 혁신성장 분야의 글로벌 \n경쟁력 확보를 위한 금융지원이 지속 추진 중임\n￮정책금융기관의 혁신성장 분야 정책금융 공급규모는 2017년 240,787 억 원에서  연평균  37.2% 증가\n하여 2021 년 854,338 억 원에 이르는 등 그 외연을 확장해나가고 있음', metadata={'page': 2, 'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf'}),
#  Document(page_content='￮또한, 미래 성장성은 유망하나 단기 수익 창출이 어려운 산업의 지원 강화를 위해 정책금융 뿐만 아니라  \n민관주도의 역동적 금융으로 혁신성장 금융지원 영역을 확대할 필요가 있음', metadata={'page': 1, 'source': '/content/drive/MyDrive/Colab Notebooks/LangChain/[이슈리포트 2022-2호] 혁신성장 정책금융 동향.pdf'}),
# ...

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0)

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
Markdown(chain.invoke({'question': "혁신성장 정책금융에 대해서 설명해줘"}).content)
# Out:
# 혁신성장 정책금융은 건강한 혁신산업 생태계를 조성하기 위해 기업 성장에 필요한 자금을 지원하는 혁신성장 정책금융 제도를 시행하고 있습니다. 혁신성장 정책금융기관은 혁신성장에 대한 정의를 구체화한 정책금융 가이드라인에 따라 혁신성장 산업육성을 위한 정책금융 업무를 추진하고 있습니다. 혁신성장 정책금융 제도 시행 이후 공급 규모가 매년 증가하는 등, 미래 혁신성장 분야의 글로벌 경쟁력 확보를 위한 금융지원이 지속 추진 중입니다. 정책금융기관의 혁신성장 분야 정책금융 공급규모는 2017년 240,787 억 원에서 연평균 37.2% 증가하여 2021 년 854,338 억 원에 이르는 등 그 외연을 확장해나가고 있습니다. 또한, 미래 성장성은 유망하나 단기 수익 창출이 어려운 산업의 지원 강화를 위해 정책금융 뿐만 아니라 민관주도의 역동적 금융으로 혁신성장 금융지원 영역을 확대할 필요가 있습니다.
